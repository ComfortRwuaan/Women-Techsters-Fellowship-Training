# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')    #import the dataset to your jupyter notebook
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
y = lambda x : x *2

# %%
y(10)
# Out:
# 20

# %%
df.Name.apply(lambda x: x.split(',')[1])
# Out:
# 0                                  Mr. Owen Harris
# 1       Mrs. John Bradley (Florence Briggs Thayer)
# 2                                      Miss. Laina
# 3               Mrs. Jacques Heath (Lily May Peel)
# 4                                Mr. William Henry
#                           ...
# 886                                    Rev. Juozas
# 887                           Miss. Margaret Edith
# 888                 Miss. Catherine Helen "Carrie"
# 889                                Mr. Karl Howell
# 890                                    Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['New Name'] =df.Name.apply(lambda x: x.split(',')[1])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['New Name'] = df['New Name'].str.strip()

# %%
df = pd.read_csv('car_emission.csv', encoding='windows-1252') #encoding is used in unicodedecode error

# %%
df
# Out:
#      Manufacturer                                     Model  \
# 0      ALFA ROMEO     MiTo Series 3, September 2016 Onwards
# 1             BMW  1 Series 3-door F21, From September 2012
# 2             BMW  1 Series 5-door F20, From September 2011
# 3         CITROEN                                        C4
# 4         CITROEN                                 C4 Cactus
# ...           ...                                       ...
# 5113        LEXUS                                 LC MY2017
# 5114        LEXUS                                 LC MY2017
# 5115     INFINITI                           Q50 Euro6, 2016
# 5116        LEXUS                           RC 200t, MY2015
# 5117        LEXUS                           RC 200t, MY2015
#
#                   Description Transmission  Engine Capacity      Fuel Type  \
# 0           1.3 JTDm-2 95 bhp           M5           1248.0         Diesel
# 1     116d ED Plus 16'' tyres           M6           1496.0         Diesel
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5118 entries, 0 to 5117
# Data columns (total 34 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Manufacturer                           5118 non-null   object
#  1   Model                                  5118 non-null   object
#  2   Description                            5118 non-null   object
#  3   Transmission                           5086 non-null   object
#  4   Engine Capacity                        5088 non-null   float64
#  5   Fuel Type                              5118 non-null   object
#  6   Electric energy consumption Miles/kWh  81 non-null     float64
#  7   wh/km                                  81 non-null     float64
#  8   Maximum range (Km)                     81 non-null     float64
#  9   Maximum range (Miles)                  81 non-null     float64
# ...

# %%
df.isna().sum()
# Out:
# Manufacturer                                0
# Model                                       0
# Description                                 0
# Transmission                               32
# Engine Capacity                            30
# Fuel Type                                   0
# Electric energy consumption Miles/kWh    5037
# wh/km                                    5037
# Maximum range (Km)                       5037
# Maximum range (Miles)                    5037
# Metric Urban (Cold)                        81
# Metric Extra-Urban                         81
# Metric Combined                            30
# Imperial Urban (Cold)                      81
# Imperial Extra-Urban                       81
# Imperial Combined                          30
# CO2 g/km                                    0
# Fuel Cost 12000 Miles                      30
# Electricity cost                         5037
# Total cost / 12000 miles                    0
# ...

# %%
#df.drop(df.iloc[:, -7], axis=1, inplace=True)

# %%
df2 = df.drop(['Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31','Unnamed: 32','Unnamed: 33'], axis=1, inplace=True)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Manufacturer                                     Model  \
# 0      ALFA ROMEO     MiTo Series 3, September 2016 Onwards
# 1             BMW  1 Series 3-door F21, From September 2012
# 2             BMW  1 Series 5-door F20, From September 2011
# 3         CITROEN                                        C4
# 4         CITROEN                                 C4 Cactus
# ...           ...                                       ...
# 5113        LEXUS                                 LC MY2017
# 5114        LEXUS                                 LC MY2017
# 5115     INFINITI                           Q50 Euro6, 2016
# 5116        LEXUS                           RC 200t, MY2015
# 5117        LEXUS                           RC 200t, MY2015
#
#                   Description Transmission  Engine Capacity      Fuel Type  \
# 0           1.3 JTDm-2 95 bhp           M5           1248.0         Diesel
# ...

# %%
df[['Fuel Cost 12000 Miles','Total cost / 12000 miles']]
# Out:
#      Fuel Cost 12000 Miles Total cost / 12000 miles
# 0                     £807                     £807
# 1                     £807                     £807
# 2                     £807                     £807
# 3                     £784                     £784
# 4                     £807                     £807
# ...                    ...                      ...
# 5113                £1,505                   £1,505
# 5114                £1,505                   £1,505
# 5115                £1,577                   £1,577
# 5116                £1,692                   £1,692
# 5117                £1,692                   £1,692
#
# [5118 rows x 2 columns]

# %%
'£807'.replace('£',"")
# Out:
# '807'

# %%
int(807)
# Out:
# 807

# %%
df['Total cost / 12000 miles'].str.replace('£',"")
# Out:
# 0         807
# 1         807
# 2         807
# 3         784
# 4         807
#         ...
# 5113    1,505
# 5114    1,505
# 5115    1,577
# 5116    1,692
# 5117    1,692
# Name: Total cost / 12000 miles, Length: 5118, dtype: object

# %%
df['Total cost / 12000 miles'] = df['Total cost / 12000 miles'].str.replace('£', "")

# %%
df['Total cost / 12000 miles'] = df['Total cost / 12000 miles'].str.replace(',', "")

# %%
df['Total cost / 12000 miles'] = df['Total cost / 12000 miles'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5118 entries, 0 to 5117
# Data columns (total 27 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Manufacturer                           5118 non-null   object
#  1   Model                                  5118 non-null   object
#  2   Description                            5118 non-null   object
#  3   Transmission                           5086 non-null   object
#  4   Engine Capacity                        5088 non-null   float64
#  5   Fuel Type                              5118 non-null   object
#  6   Electric energy consumption Miles/kWh  81 non-null     float64
#  7   wh/km                                  81 non-null     float64
#  8   Maximum range (Km)                     81 non-null     float64
#  9   Maximum range (Miles)                  81 non-null     float64
# ...
